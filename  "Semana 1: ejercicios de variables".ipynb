# %% [markdown]
# <a href="https://colab.research.google.com/github/andreycastillocrc30/-aprendiendo-python-/blob/main/%20%22Semana%201%3A%20ejercicios%20de%20variables%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"semana01_py4e.ipynb"
# Out:
# 'semana01_py4e.ipynb'

# %%
"Hola Andrey"
# Out:
# 'Hola Andrey'
